# %%
import pandas as pd

# %%
my_dict = {'rating':['a', 'a', 'a', 'b', 'b'], 'age':[10, 20, 30, 40, 50], 'salary':[50,40,30,20,10]}
df = pd.DataFrame(my_dict)
df.head()
# Out:
#   rating  age  salary
# 0      a   10      50
# 1      a   20      40
# 2      a   30      30
# 3      b   40      20
# 4      b   50      10

# %%
avg_df = df.groupby(df['rating']).mean()
avg_df.head()
# Out:
#          age  salary
# rating
# a       20.0    40.0
# b       45.0    15.0

# %%
df_a = pd.DataFrame()
df_a['new_salary'] = df.loc[df['rating'] == 'a'][['salary']]*.1 + df.loc[df['rating'] == 'a'][['salary']]
#df_a.drop(['salary'], axis = 1)
df_a
# Out:
#    new_salary
# 0        55.0
# 1        44.0
# 2        33.0

# %%
df_b = pd.DataFrame()
df_b['new_salary'] = df.loc[df['rating'] == 'b'][['salary']]*.2 + df.loc[df['rating'] == 'b'][['salary']]
#df_b.drop(['salary'], axis = 1)
df_b
# Out:
#    new_salary
# 3        24.0
# 4        12.0

# %%
inc = {'a':10, 'b':20}
#df_a = df.loc[df['rating'] == 'a']

# %%
inc_dict = {'a':10, 'b':20}

# %%
#Pokeman datasets
df = pd.read_csv('/Users/bimle/Desktop/PersonalProject/Pandas/pandas-master/pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df1 = df.groupby(['Type 1']).sum().sort_values('Sp. Def', ascending=False)
df1
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Water     33946  8071    8305     8170     8379     7898   7388         320
# Normal    31279  7573    7200     5865     5470     6245   7012         299
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Psychic   21706  4026    4073     3858     5609     4918   4645         193
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Rock      17280  2876    4086     4435     2787     3321   2460         152
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Steel     11957  1761    2503     3412     1823     2177   1492         104
# ...

# %%
df.shape
# Out:
# (800, 12)

# %%
df2 = df.groupby(['Type 2','Type 1']).mean().sort_values('Defense', ascending = False)
df2
# Out:
#                            #          HP      Attack     Defense     Sp. Atk  \
# Type 2  Type 1
# Ground  Steel     208.000000   75.000000  105.000000  215.000000   55.000000
# Fire    Ground    383.000000  100.000000  180.000000  160.000000  150.000000
# Rock    Bug       442.666667   46.666667   56.666667  146.666667   36.666667
# Steel   Rock      432.333333   50.000000   49.666667  143.666667   54.666667
# Rock    Steel     305.000000   60.000000   90.000000  140.000000   50.000000
# ...                      ...         ...         ...         ...         ...
# Ghost   Bug       292.000000    1.000000   90.000000   45.000000   30.000000
# Normal  Electric  694.500000   53.000000   46.500000   42.500000   85.000000
# Flying  Ghost     425.500000  120.000000   65.000000   39.000000   75.000000
# Water   Bug       283.000000   40.000000   30.000000   32.000000   50.000000
# Psychic Ice       181.000000   55.000000   40.000000   25.000000  100.000000
#
# ...

# %%
df.query("Defense>50")
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 5      5             Charmeleon     Fire     NaN  58      64       58
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# ...

# %%
df.query('Name=="Ivysaur"')
# Out:
#    #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2  Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 1           1      False
